# %%
from google_play_scraper import Sort, reviews,reviews_all
import pandas as pd

# %%
# initialization

app_name = 'com.mcdonalds.mobileapp' # found in app's url

rvws, token = reviews(
    app_name,           # found in app's url
    lang='en',        # defaults to 'en'
    country='us',     # defaults to 'us'
    sort=Sort.NEWEST, # start with most recent
    count=200       # batch size, set as 200 since 200 reviews per page
)

app_reviews = rvws
batch_num=1

# %%
print(app_reviews)
print(token)

# %%
# Loop through the number of batches
for batch in range(500): # You can adjust the number of batches to collect more or less reviews
    rvws, token = reviews( # store continuation_token
        app_name,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        # using token obtained from previous batch
        continuation_token=token
    )
    app_reviews.extend(rvws)
    batch_num +=1

# %%
df = pd.DataFrame.from_records(app_reviews)
df
# Out:
#                                                  reviewId          userName  \
# 0       gp:AOqpTOGPq-8LyHiMTNXU216EeMbZv0vbeUrcLNKQuSr...      Harith Bolhi
# 1       gp:AOqpTOHrGSZxs32JpFDMuY1zjZ4oTqyGJU_9kS2r4ZN...       ahmad gouda
# 2       gp:AOqpTOFgvhDSTrHxsa95OR_-gMKIbQPArQpFLnBYQfH...     Iwan Langitan
# 3       gp:AOqpTOFt54B_DiDLR2BZt72Zg-iE2e5trTFWcCp3ahu...      muhamad faez
# 4       gp:AOqpTOGmQzwBWWYh6ov5Lgxwpfxob21m2E0674WFJeS...       DJ KNOXX SA
# ...                                                   ...               ...
# 100029  gp:AOqpTOEN3m_Ytja3dRXCie-eAZMPOUsWla501__tg__...        Remi Mesut
# 100030  gp:AOqpTOEwSBYSeWSqfuOwBNgMhLJpi3xMK4Nkyd7sV73...     nidhin thomas
# 100031  gp:AOqpTOEWX_17hzmzkUU4XRD9sb_ybOYerk-g9kvfiCV...      Bahaa Abdeen
# 100032  gp:AOqpTOFymEEpfl7bkpIO3eehU48rnnrHVWFqhGukfvA...        SirajMunir
# 100033  gp:AOqpTOGBg9nvJ4WNM-uBu4W8BfbymHGCRkqfQWc8T87...  Abo Omar Barakat
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a-/AOh14...
# 1       https://play-lh.googleusercontent.com/a-/AOh14...
# 2       https://play-lh.googleusercontent.com/a-/AOh14...
# 3       https://play-lh.googleusercontent.com/a-/AOh14...
# 4       https://play-lh.googleusercontent.com/a-/AOh14...
# ...                                                   ...
# 100029  https://play-lh.googleusercontent.com/a-/AOh14...
# 100030  https://play-lh.googleusercontent.com/a-/AOh14...
# 100031  https://play-lh.googleusercontent.com/a/AATXAJ...
# 100032  https://play-lh.googleusercontent.com/a-/AOh14...
# 100033  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                                   content  score  \
# 0                                    Slow gila management      1
# 1                                                 Bad app      1
# 2                           Otp code never receive bad...      1
# 3       Stupid app...say my device did not pass securi...      1
# 4       The app is not working and wants an update jus...      1
# ...                                                   ...    ...
# 100029              Nedense şubeye gidince çalışmıyor ...      1
# 100030                                            Good :)      5
# 100031                        خدمة العملاء سيئة جداً جداً      1
# 100032                                      McDonald's Tq      5
# 100033                                Bad Difficult login      3
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   0               2.23.1 2021-07-11 14:08:26         None
# 1                   0                 None 2021-07-11 12:36:06         None
# 2                   0                 None 2021-07-11 12:12:44         None
# 3                   0               2.23.1 2021-07-11 10:19:40         None
# 4                   0               2.23.1 2021-07-11 09:44:01         None
# ...               ...                  ...                 ...          ...
# 100029              0                2.5.4 2020-06-12 03:12:04         None
# 100030              0                2.5.3 2020-06-12 01:59:34         None
# 100031              0                2.5.4 2020-06-12 00:55:53         None
# 100032              0                2.5.4 2020-06-12 00:34:55         None
# 100033              1                2.6.0 2020-06-12 00:24:45         None
#
#        repliedAt
# 0            NaT
# 1            NaT
# 2            NaT
# 3            NaT
# 4            NaT
# ...          ...
# 100029       NaT
# 100030       NaT
# 100031       NaT
# 100032       NaT
# 100033       NaT
#
# [100034 rows x 10 columns]

# %%
df.to_csv('macdonalds_reviews.csv',index=False)

# %%
df.score.value_counts()
# Out:
# 1    47531
# 5    39053
# 4     5186
# 2     4496
# 3     3768
# Name: score, dtype: int64
